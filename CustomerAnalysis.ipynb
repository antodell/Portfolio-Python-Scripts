# %% [markdown]
#  # Customer Analysis

# %% [markdown]
# Customer Segmentation for Marketing

# %%
import pandas as pd

# %%
cst = pd.read_csv(r'C:\Users\antoo\OneDrive\Documents\Coderhouse\coderhouse_ds31500-main\coderhouse_ds31500-main\customer_segmentation.csv')

# %%
cst.head(15)
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   5524        1957  Graduation         Single  58138.0        0         0
# 1   2174        1954  Graduation         Single  46344.0        1         1
# 2   4141        1965  Graduation       Together  71613.0        0         0
# 3   6182        1984  Graduation       Together  26646.0        1         0
# 4   5324        1981         PhD        Married  58293.0        1         0
# 5   7446        1967      Master       Together  62513.0        0         1
# 6    965        1971  Graduation       Divorced  55635.0        0         1
# 7   6177        1985         PhD        Married  33454.0        1         0
# 8   4855        1974         PhD       Together  30351.0        1         0
# 9   5899        1950         PhD       Together   5648.0        1         1
# 10  1994        1983  Graduation        Married      NaN        1         0
# ...

# %%
print("Number of datapoints:", len(cst))
# Out:
# Number of datapoints: 2240

# %% [markdown]
# The dataset has been chosen to perform a customer segmentation and predict what type of producst would be better to launch and to communicate to each specific customer according to their segmentation.

# %%
cst.columns.unique().shape
# Out:
# (20,)

# %%
cst.isna()
# Out:
#          ID  Year_Birth  Education  Marital_Status  Income  Kidhome  Teenhome  \
# 0     False       False      False           False   False    False     False
# 1     False       False      False           False   False    False     False
# 2     False       False      False           False   False    False     False
# 3     False       False      False           False   False    False     False
# 4     False       False      False           False   False    False     False
# ...     ...         ...        ...             ...     ...      ...       ...
# 2235  False       False      False           False   False    False     False
# 2236  False       False      False           False   False    False     False
# 2237  False       False      False           False   False    False     False
# 2238  False       False      False           False   False    False     False
# 2239  False       False      False           False   False    False     False
#
# ...

# %%
cst.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# dtype: int64

# %%
cst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
cst.isna().sum() / len(cst)
# Out:
# ID                     0.000000
# Year_Birth             0.000000
# Education              0.000000
# Marital_Status         0.000000
# Income                 0.010714
# Kidhome                0.000000
# Teenhome               0.000000
# Dt_Customer            0.000000
# Recency                0.000000
# MntWines               0.000000
# MntFruits              0.000000
# MntMeatProducts        0.000000
# MntFishProducts        0.000000
# MntSweetProducts       0.000000
# MntGoldProds           0.000000
# NumDealsPurchases      0.000000
# NumWebPurchases        0.000000
# NumCatalogPurchases    0.000000
# NumStorePurchases      0.000000
# NumWebVisitsMonth      0.000000
# dtype: float64

# %%
cst.dropna()
print('The total number of rows after removing the missing values are:'), len(cst)
# Out:
# The total number of rows after removing the missing values are:
# (None, 2240)

# %% [markdown]
# With these calculations I can determine that the data is at the moment useful to start further analysis.

# %%
cst.tail()
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2236   4001        1946         PhD       Together  64014.0        2
# 2237   7270        1981  Graduation       Divorced  56981.0        0
# 2238   8235        1956      Master       Together  69245.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 2235         1  13/06/2013       46       709         43              182
# 2236         1  10/06/2014       56       406          0               30
# 2237         0  25/01/2014       91       908         48              217
# 2238         1  24/01/2014        8       428         30              214
# 2239         1  15/10/2012       40        84          3               61
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# ...

# %%
cst.Marital_Status == 'Married'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2235     True
# 2236    False
# 2237    False
# 2238    False
# 2239     True
# Name: Marital_Status, Length: 2240, dtype: bool

# %%
mask = cst.Marital_Status == 'Married'

# %%
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2235     True
# 2236    False
# 2237    False
# 2238    False
# 2239     True
# Name: Marital_Status, Length: 2240, dtype: bool

# %%
cst[mask]
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 4      5324        1981         PhD        Married  58293.0        1
# 7      6177        1985         PhD        Married  33454.0        1
# 10     1994        1983  Graduation        Married      NaN        1
# 11      387        1976       Basic        Married   7500.0        0
# 14     2569        1987  Graduation        Married  17323.0        0
# ...     ...         ...         ...            ...      ...      ...
# 2226   4478        1979  Graduation        Married  63777.0        1
# 2229  10084        1972  Graduation        Married  24434.0        2
# 2234   8372        1974  Graduation        Married  34421.0        1
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
cst.groupby(['Marital_Status']).count()
# Out:
#                  ID  Year_Birth  Education  Income  Kidhome  Teenhome  \
# Marital_Status
# Absurd            2           2          2       2        2         2
# Alone             3           3          3       3        3         3
# Divorced        232         232        232     232      232       232
# Married         864         864        864     857      864       864
# Single          480         480        480     471      480       480
# Together        580         580        580     573      580       580
# Widow            77          77         77      76       77        77
# YOLO              2           2          2       2        2         2
#
#                 Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# Marital_Status
# Absurd                    2        2         2          2                2
# Alone                     3        3         3          3                3
# Divorced                232      232       232        232              232
# ...

# %%
cst.NumWebPurchases.sum()
# Out:
# 9150

# %%
cst.NumStorePurchases.sum()
# Out:
# 12970

# %%
type(cst.ID)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Google PlayStore Analysis

# %%
google  = pd.read_csv(r'C:\Users\antoo\OneDrive\Documents\Coderhouse\coderhouse_ds31500-main\coderhouse_ds31500-main\googleplaystore.csv')

# %%
google.head(15)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
google.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
print(google.shape)
# Out:
# (10841, 13)

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Se realizara un analisis de la tienda de Google con su cantidad de descargas y rating ademas de ver cuales son las mas aclamadas por el publico en base a las caracteristicas de las aplicaciones.

# %% [markdown]
# # Covid Vaccinations

# %%
covid = pd.read_csv(r"C:\Users\antoo\OneDrive\Documents\Coderhouse\coderhouse_ds31500-main\coderhouse_ds31500-main\CovidVaccinations.csv")

# %%
covid.head(10)
# Out:
#   iso_code continent     location        date  new_tests  \
# 0      AFG      Asia  Afghanistan  24/02/2020        NaN
# 1      AFG      Asia  Afghanistan  25/02/2020        NaN
# 2      AFG      Asia  Afghanistan  26/02/2020        NaN
# 3      AFG      Asia  Afghanistan  27/02/2020        NaN
# 4      AFG      Asia  Afghanistan  28/02/2020        NaN
# 5      AFG      Asia  Afghanistan  29/02/2020        NaN
# 6      AFG      Asia  Afghanistan  01/03/2020        NaN
# 7      AFG      Asia  Afghanistan  02/03/2020        NaN
# 8      AFG      Asia  Afghanistan  03/03/2020        NaN
# 9      AFG      Asia  Afghanistan  04/03/2020        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# ...

# %%
print(covid.shape)
# Out:
# (194748, 45)

# %%
covid.describe()
# Out:
#           new_tests  total_tests_per_thousand  new_tests_per_thousand  \
# count  7.462100e+04              78521.000000            74621.000000
# mean   6.698367e+04                904.457824                3.239427
# std    2.486109e+05               2146.352032                8.951406
# min    1.000000e+00                  0.000000                0.000000
# 25%    2.227000e+03                 42.858000                0.284000
# 50%    8.674000e+03                230.082000                0.962000
# 75%    3.634900e+04                880.721000                2.911000
# max    3.585563e+07              32925.900000              534.013000
#
#        new_tests_smoothed  new_tests_smoothed_per_thousand  positive_rate  \
# count        1.029270e+05                    102927.000000   94858.000000
# mean         1.428613e+05                         2.801438       0.099064
# std          1.143856e+06                         7.282324       0.118393
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194748 entries, 0 to 194747
# Data columns (total 45 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    194748 non-null  object
#  1   continent                                   183440 non-null  object
#  2   location                                    194748 non-null  object
#  3   date                                        194748 non-null  object
#  4   new_tests                                   74621 non-null   float64
#  5   total_tests_per_thousand                    78521 non-null   float64
#  6   new_tests_per_thousand                      74621 non-null   float64
#  7   new_tests_smoothed                          102927 non-null  float64
#  8   new_tests_smoothed_per_thousand             102927 non-null  float64
# ...

# %% [markdown]
# Se evaluara la cantidad de vacunados por pais desde el inicio de las mismas con respecto a su poblacion e ubicacion.

# %%
covid[covid.location == 'Argentina'].location.count()
# Out:
# 899

# %% [markdown]
# Se han encontrado 899 registros de vacunacion hasta el dia de '17-06-2022' en Argentina que se podran evaluar.

# %%
covid[covid.location == 'Argentina'].tail()
# Out:
#      iso_code      continent   location        date  new_tests  \
# 7580      ARG  South America  Argentina  13/06/2022        NaN
# 7581      ARG  South America  Argentina  14/06/2022        NaN
# 7582      ARG  South America  Argentina  15/06/2022        NaN
# 7583      ARG  South America  Argentina  16/06/2022        NaN
# 7584      ARG  South America  Argentina  17/06/2022        NaN
#
#       total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 7580                       NaN                     NaN                 NaN
# 7581                       NaN                     NaN                 NaN
# 7582                       NaN                     NaN                 NaN
# 7583                       NaN                     NaN                 NaN
# 7584                       NaN                     NaN                 NaN
#
#       new_tests_smoothed_per_thousand  positive_rate  ...  female_smokers  \
# ...

# %%
type(covid)
# Out:
# pandas.core.frame.DataFrame

# %%
covid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
# ...

# %%
covid.mean()
# Out:
# C:\Users\antoo\AppData\Local\Temp\ipykernel_8216\1682108217.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   covid.mean()
# new_tests                                     6.698367e+04
# total_tests_per_thousand                      9.044578e+02
# new_tests_per_thousand                        3.239427e+00
# new_tests_smoothed                            1.428613e+05
# new_tests_smoothed_per_thousand               2.801438e+00
# positive_rate                                 9.906427e-02
# tests_per_case                                2.421731e+03
# total_vaccinations                            2.328700e+08
# people_vaccinated                             1.125793e+08
# people_fully_vaccinated                       9.411487e+07
# total_boosters                                4.031930e+07
# ...

# %%
covid['new_vaccinations'].hist()
# Out:
# <AxesSubplot:>

# %%
covid['continent']
# Out:
# 0           Asia
# 1           Asia
# 2           Asia
# 3           Asia
# 4           Asia
#            ...
# 194743    Africa
# 194744    Africa
# 194745    Africa
# 194746    Africa
# 194747    Africa
# Name: continent, Length: 194748, dtype: object

# %%
covid[covid.date == '17/06/2022'].head()
# Out:
#       iso_code continent     location        date  new_tests  \
# 844        AFG      Asia  Afghanistan  17/06/2022        NaN
# 1700  OWID_AFR       NaN       Africa  17/06/2022        NaN
# 2544       ALB    Europe      Albania  17/06/2022        NaN
# 3388       DZA    Africa      Algeria  17/06/2022        NaN
# 4226       AND    Europe      Andorra  17/06/2022        NaN
#
#       total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 844                        NaN                     NaN                 NaN
# 1700                       NaN                     NaN                 NaN
# 2544                       NaN                     NaN                 NaN
# 3388                       NaN                     NaN                 NaN
# 4226                       NaN                     NaN                 NaN
#
#       new_tests_smoothed_per_thousand  positive_rate  ...  female_smokers  \
# ...
